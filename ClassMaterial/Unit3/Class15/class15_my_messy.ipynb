# %%
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
# this is the file you should've gotten from your repo
from utils import extract_dates, get_val_scores
from category_encoders import OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, train_test_split

# %%
df = pd.read_csv('../data/ks2.csv', encoding='utf-8', parse_dates=['deadline' , 'launched'])

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline            launched  \
# 0          Poetry    Publishing      GBP 2015-10-09 2015-08-11 12:12:28
# 1  Narrative Film  Film & Video      USD 2017-11-01 2017-09-02 04:43:57
# 2  Narrative Film  Film & Video      USD 2013-02-26 2013-01-12 00:20:50
# 3           Music         Music      USD 2012-04-16 2012-03-17 03:24:11
# 4    Film & Video  Film & Video      USD 2015-08-29 2015-07-04 08:35:03
#
#     state country      goal
# 0  failed      GB   1533.95
# 1  failed      US  30000.00
# 2  failed      US  45000.00
# 3  failed      US   5000.00
# 4  failed      US  19500.00

# %%
df = extract_dates(df)

# %%
df.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'launched', 'state', 'country', 'goal', 'deadline_dayofweek',
#        'deadline_dayofyear', 'deadline_days_in_month', 'deadline_is_leap_year',
#        'deadline_is_month_end', 'deadline_is_month_start',
#        'deadline_is_quarter_end', 'deadline_is_quarter_start',
#        'deadline_is_year_end', 'deadline_is_year_start', 'deadline_quarter',
#        'deadline_week', 'deadline_weekofyear', 'deadline_day', 'deadline_hour',
#        'deadline_minute', 'deadline_month', 'deadline_year',
#        'launched_dayofweek', 'launched_dayofyear', 'launched_days_in_month',
#        'launched_is_leap_year', 'launched_is_month_end',
#        'launched_is_month_start', 'launched_is_quarter_end',
#        'launched_is_quarter_start', 'launched_is_year_end',
#        'launched_is_year_start', 'launched_quarter', 'launched_week',
#        'launched_weekofyear', 'launched_day', 'launched_hour',
#        'launched_minute', 'launched_month', 'launched_year',
#        'deadline_history_days', 'launched_history_days'],
#       dtype='object')

# %%
mod1 = xgb.XGBClassifier()

# %%
mod1.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': 'gain',
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
X = df.drop(['deadline', 'launched', 'state'], axis=1)
y = df['state']

# %%
pipe = make_pipeline(OrdinalEncoder(), mod1)

# %%
scores = get_val_scores(pipe, X, y, return_test_score=True, random_state=1985, stratify=True, use_kfold=False)

# %%
scores
# Out:
# {'validation_score': 0.7263509523729186, 'test_score': 0.7005304287970199}

# %%
feats = pd.DataFrame({ 'Importance': pipe.steps[1][1].feature_importances_, 'Column': X.columns})
feats.sort_values(by='Importance', ascending=False)
# Out:
#     Importance                     Column
# 6     0.123426                       goal
# 3     0.087642              main_category
# 2     0.082025                   category
# 43    0.053122      deadline_history_days
# 41    0.050469             launched_month
# 30    0.041295    launched_is_month_start
# 39    0.041036              launched_hour
# 44    0.036439      launched_history_days
# 4     0.035812                   currency
# 5     0.034382                    country
# 25    0.029260         launched_dayofweek
# 18    0.028919              deadline_week
# 29    0.026881      launched_is_month_end
# 40    0.026286            launched_minute
# 7     0.023354         deadline_dayofweek
# 26    0.022033         launched_dayofyear
# 8     0.019626         deadline_dayofyear
# 31    0.017831    launched_is_quarter_end
# 23    0.017812             deadline_month
# 38    0.017527               launched_day
# 9     0.015785     deadline_days_in_month
# 20    0.015129               deadline_day
# 42    0.014881              launched_year
# 11    0.014585      deadline_is_month_end
# 35    0.013890           launched_quarter
# 36    0.013559              launched_week
# 27    0.013261     launched_days_in_month
# 32    0.012796  launched_is_quarter_start
# 14    0.012422  deadline_is_quarter_start
# 24    0.010531              deadline_year
# 0     0.010430                         ID
# 1     0.010352                       name
# 28    0.010247      launched_is_leap_year
# 12    0.009920    deadline_is_month_start
# 10    0.007034      deadline_is_leap_year
# 33    0.000000       launched_is_year_end
# 34    0.000000     launched_is_year_start
# 21    0.000000              deadline_hour
# 19    0.000000        deadline_weekofyear
# 37    0.000000        launched_weekofyear
# 17    0.000000           deadline_quarter
# 16    0.000000     deadline_is_year_start
# 15    0.000000       deadline_is_year_end
# 13    0.000000    deadline_is_quarter_end
# 22    0.000000            deadline_minute

# %%
df['duration'] = (df['deadline'] - df['launched']).dt.days

# %%
cat_avgs = df.groupby('category')[['goal']].mean().rename({'goal': 'category_goal_avg'}, axis=1)

# %%
df = df.merge(cat_avgs, left_on='category', right_index = True)

# %%
df['cat_goal_pct'] = df['goal'] / df['category_goal_avg']

# %%
cat_avgs = df.groupby('main_category')[['goal']].mean().rename({'goal': 'main_category_goal_avg'}, axis=1)

# %%
df = df.merge(cat_avgs, left_on='main_category', right_index = True)

# %%
df['main_cat_goal_pct'] = df['goal'] / df['main_category_goal_avg']

# %%
df[['goal', 'main_category_goal_avg', 'main_cat_goal_pct']].head()
# Out:
#          goal  main_category_goal_avg  main_cat_goal_pct
# 0     1533.95            22590.745149           0.067902
# 232   6060.97            22590.745149           0.268294
# 318   2000.00            22590.745149           0.088532
# 414  10000.00            22590.745149           0.442659
# 517    757.52            22590.745149           0.033532

# %%
X = df.drop(['deadline', 'launched', 'state'], axis=1)
y = df['state']

# %%
scores = get_val_scores(pipe, X, y, random_state=1985, stratify=True, use_kfold=False)

# %%
scores
# Out:
# {'validation_score': 0.7310411148414961}

# %%
weekly_totals = df.groupby(['launched_year','launched_weekofyear'])[['ID']].count().reset_index().rename({'ID': 'Daily_Campaigns'}, axis=1)

# %%
weekly_totals.head()
# Out:
#    launched_year  launched_weekofyear  Daily_Campaigns
# 0           1970                    1                6
# 1           2009                   17                4
# 2           2009                   18               22
# 3           2009                   19               17
# 4           2009                   20               23

# %%
df.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'launched', 'state', 'country', 'goal', 'deadline_dayofweek',
#        'deadline_dayofyear', 'deadline_days_in_month', 'deadline_is_leap_year',
#        'deadline_is_month_end', 'deadline_is_month_start',
#        'deadline_is_quarter_end', 'deadline_is_quarter_start',
#        'deadline_is_year_end', 'deadline_is_year_start', 'deadline_quarter',
#        'deadline_week', 'deadline_weekofyear', 'deadline_day', 'deadline_hour',
#        'deadline_minute', 'deadline_month', 'deadline_year',
#        'launched_dayofweek', 'launched_dayofyear', 'launched_days_in_month',
#        'launched_is_leap_year', 'launched_is_month_end',
#        'launched_is_month_start', 'launched_is_quarter_end',
#        'launched_is_quarter_start', 'launched_is_year_end',
#        'launched_is_year_start', 'launched_quarter', 'launched_week',
#        'launched_weekofyear', 'launched_day', 'launched_hour',
#        'launched_minute', 'launched_month', 'launched_year',
#        'deadline_history_days', 'launched_history_days', 'duration',
#        'category_goal_avg', 'cat_goal_pct', 'main_category_goal_avg',
#        'main_cat_goal_pct'],
#       dtype='object')

# %%
df.merge(weekly_totals, on=['launched_year', 'launched_year'])
# Out:
#                   ID                                               name  \
# 0         1000002330                    The Songs of Adelaide & Abullah
# 1         1000002330                    The Songs of Adelaide & Abullah
# 2         1000002330                    The Songs of Adelaide & Abullah
# 3         1000002330                    The Songs of Adelaide & Abullah
# 4         1000002330                    The Songs of Adelaide & Abullah
# ...              ...                                                ...
# 19384373   462917959     Identity Communications Infographic (Canceled)
# 19384374  1480763647  Support Solo Theater! Help "Ungrateful Daughte...
# 19384375  1245461087  1st Super-Size Painting - Social Network Owned...
# 19384376  1078942938        Resilience: 5-6 Player Expansion Board Game
# 19384377  1854247643                                  100 Acres of Hell
#
#                 category main_category currency   deadline  \
# 0                 Poetry    Publishing      GBP 2015-10-09
# 1                 Poetry    Publishing      GBP 2015-10-09
# 2                 Poetry    Publishing      GBP 2015-10-09
# 3                 Poetry    Publishing      GBP 2015-10-09
# 4                 Poetry    Publishing      GBP 2015-10-09
# ...                  ...           ...      ...        ...
# 19384373          Design        Design      USD 2010-04-10
# 19384374         Theater       Theater      USD 2010-06-01
# 19384375             Art           Art      USD 2010-08-14
# 19384376  Tabletop Games         Games      CAD 2018-02-01
# 19384377     Comic Books        Comics      GBP 2018-01-15
#
#                     launched   state country      goal  ...  launched_year  \
# 0        2015-08-11 12:12:28  failed      GB   1533.95  ...           2015
# 1        2015-08-11 12:12:28  failed      GB   1533.95  ...           2015
# 2        2015-08-11 12:12:28  failed      GB   1533.95  ...           2015
# 3        2015-08-11 12:12:28  failed      GB   1533.95  ...           2015
# 4        2015-08-11 12:12:28  failed      GB   1533.95  ...           2015
# ...                      ...     ...     ...       ...  ...            ...
# 19384373 1970-01-01 01:00:00  failed      US    500.00  ...           1970
# 19384374 1970-01-01 01:00:00  failed      US   4000.00  ...           1970
# 19384375 1970-01-01 01:00:00  failed      US  15000.00  ...           1970
# 19384376 2018-01-02 03:05:10  failed      CA   3993.93  ...           2018
# 19384377 2018-01-01 00:54:41  failed      GB    136.40  ...           2018
#
#           deadline_history_days  launched_history_days  duration  \
# 0                          2350                  16658        58
# 1                          2350                  16658        58
# 2                          2350                  16658        58
# 3                          2350                  16658        58
# 4                          2350                  16658        58
# ...                         ...                    ...       ...
# 19384373                    342                      0     14708
# 19384374                    394                      0     14760
# 19384375                    468                      0     14834
# 19384376                   3196                  17533        29
# 19384377                   3179                  17531        13
#
#           category_goal_avg  cat_goal_pct  main_category_goal_avg  \
# 0               5213.996468      0.294199            22590.745149
# 1               5213.996468      0.294199            22590.745149
# 2               5213.996468      0.294199            22590.745149
# 3               5213.996468      0.294199            22590.745149
# 4               5213.996468      0.294199            22590.745149
# ...                     ...           ...                     ...
# 19384373       40774.916305      0.012262            42199.323873
# 19384374       12753.348309      0.313643            27147.451041
# 19384375       47852.242038      0.313465            39467.623304
# 19384376       14743.957398      0.270886            45148.243871
# 19384377        5738.923354      0.023768            19675.773316
#
#           main_cat_goal_pct  launched_weekofyear_y  Daily_Campaigns
# 0                  0.067902                      1              387
# 1                  0.067902                      2             1123
# 2                  0.067902                      3             1538
# 3                  0.067902                      4             1687
# 4                  0.067902                      5             1825
# ...                     ...                    ...              ...
# 19384373           0.011849                      1                6
# 19384374           0.147343                      1                6
# 19384375           0.380058                      1                6
# 19384376           0.088463                      1                2
# 19384377           0.006932                      1                2
#
# [19384378 rows x 55 columns]
